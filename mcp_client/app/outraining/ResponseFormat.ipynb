# %% [markdown]
# | Agent Type                                       | Default Output Format                          | Notes                               |
# | ------------------------------------------------ | ---------------------------------------------- | ----------------------------------- |
# | ZERO_SHOT_REACT_DESCRIPTION                      | Plain text (final answer)                      | Reasoning shown in verbose/debug    |
# | CHAT_ZERO_SHOT_REACT_DESCRIPTION                 | Message object or string (plain/Markdown/JSON) | Chat models; format by prompt       |
# | STRUCTURED_CHAT_ZERO_SHOT_REACT_DESCRIPTION      | JSON/dict (structured)                         | Enforced with output parser         |
# | CONVERSATIONAL_REACT_DESCRIPTION                 | Plain text or message object                   | Emphasizes conversational flow      |
# | Custom Prompt + OutputParser                     | Anything (JSON, table, etc.)                   | You define format via parser/prompt |
